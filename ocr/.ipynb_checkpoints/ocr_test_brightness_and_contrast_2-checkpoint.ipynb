# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pytesseract
# %matplotlib inline

# %%
# %pwd
# Out:
# '/Users/zzh/study/jupyter-notebook/ocr'

# %%
# img_s=cv2.imread("img/IDCard001.png")
img_s=cv2.imread("img/IDCard002.jpg")
# img_s=cv2.imread("img/IDCard003.jpg")
# img_s=cv2.imread("img/IDCard004.jpg")
# img_s=cv2.imread("img/IDCard005.jpg")
# img_s=cv2.imread("img/IDCard006.jpg")
img_s=cv2.cvtColor(img_s, cv2.COLOR_BGR2RGB)
plt.imshow(img_s)

# %%
img_rs=cv2.resize(img_s,(214*5, 135*5),interpolation=cv2.INTER_AREA )
plt.imshow(img_rs)

# %%
type(img_rs)
# Out:
# numpy.ndarray

# %%
img_rs_copy=img_rs.copy()
type(img_rs_copy)
# Out:
# numpy.ndarray

# %%
# region=img_rs_copy[400:550,50:180]
region1=img_rs_copy[400:402,50:52]
plt.imshow(region1)

# %%
region1
# Out:
# array([[[190, 194, 195],
#         [189, 195, 195]],
#
#        [[196, 201, 202],
#         [187, 193, 193]]], dtype=uint8)

# %%
region2=img_rs_copy[180:182,225:227]
plt.imshow(region2)

# %%
region2
# Out:
# array([[[30, 30, 28],
#         [41, 41, 39]],
#
#        [[28, 28, 26],
#         [32, 32, 30]]], dtype=uint8)

# %%
region1_hsv=cv2.cvtColor(region1,cv2.COLOR_RGB2HSV)
region1_hsv
# Out:
# array([[[ 96,   7, 195],
#         [ 90,   8, 195]],
#
#        [[ 95,   8, 202],
#         [ 90,   8, 193]]], dtype=uint8)

# %%
region2_hsv=cv2.cvtColor(region2,cv2.COLOR_RGB2HSV)
region2_hsv
# Out:
# array([[[30, 17, 30],
#         [30, 12, 41]],
#
#        [[30, 18, 28],
#         [30, 16, 32]]], dtype=uint8)

# %%
region1_hsv[:,:,2] -=50
region1_hsv
# Out:
# array([[[ 96,   7, 145],
#         [ 90,   8, 145]],
#
#        [[ 95,   8, 152],
#         [ 90,   8, 143]]], dtype=uint8)

# %%
region1_hsv_rgb=cv2.cvtColor(region1_hsv,cv2.COLOR_HSV2RGB)
region1_hsv_rgb
# Out:
# array([[[141, 144, 145],
#         [140, 145, 145]],
#
#        [[147, 151, 152],
#         [139, 143, 143]]], dtype=uint8)

# %%
plt.imshow(region1_hsv_rgb)

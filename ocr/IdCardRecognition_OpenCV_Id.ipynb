# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pytesseract
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-98fd8715355b> in <module>()
# ----> 1 import cv2
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#       4 import pytesseract
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ImportError: No module named 'cv2'

# %%
img=cv2.imread("D:\\tmp\\IDCard001.png")
# img=cv2.imread("D:\\tmp\\IDCard002.jpg")
img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img=cv2.resize(img,(214*5, 135*5),interpolation=cv2.INTER_CUBIC)
plt.imshow(img)

# %%
img=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
plt.imshow(img)

# %%
# roi1=img[100:110,210:220]
# plt.imshow(roi1)

# %%
# np.set_printoptions(threshold=np.inf)
# print(roi1)

# %%
# img=img[75:130,180:400]
# img=img[540:610,350:970]
# img=img[580:600,407:425]
img=img[320:560,180:670]
plt.imshow(img)
# print(img)

# %%
cv2.normalize(img,img, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX)
plt.imshow(img)
# print(img)

# %%
ret1,th1=cv2.threshold(img,100,255,cv2.THRESH_BINARY)
plt.imshow(th1)

# %%
code = pytesseract.image_to_string(th1,lang="chi_sim")
code
# Out:
# '湖南省永兴县夏和乡梓木\n村五组'
